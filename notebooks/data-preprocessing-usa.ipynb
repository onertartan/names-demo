# %%
import os
os.chdir("G:\\PycharmProjects\\tartan-names")
os.getcwd()
# Out:
# 'G:\\PycharmProjects\\tartan-names'

# %%
import pandas as pd
import os
import polars as pl
# folder containing your files
folder_path = "data/raw/names-usa/namesbystate"

# list all files (adjust extension if needed)
files = [f for f in os.listdir(folder_path) if f.endswith(".TXT")]

df_list = []

for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path,header=None,names=["state", "gender", "year", "name", "count"])
    df_list.append(df)

# combine all files into one dataframe
df = pd.concat(df_list, ignore_index=True)
df.head()
# Out:
#   state gender  year      name  count
# 0    AK      F  1910      Mary     14
# 1    AK      F  1910     Annie     12
# 2    AK      F  1910      Anna     10
# 3    AK      F  1910  Margaret      8
# 4    AK      F  1910     Helen      7

# %%
state_map = {
    'AK': 'Alaska', 'AL': 'Alabama', 'AR': 'Arkansas', 'AZ': 'Arizona',
    'CA': 'California', 'CO': 'Colorado', 'CT': 'Connecticut',
    'DC': 'District of Columbia', 'DE': 'Delaware', 'FL': 'Florida',
    'GA': 'Georgia', 'HI': 'Hawaii', 'IA': 'Iowa', 'ID': 'Idaho',
    'IL': 'Illinois', 'IN': 'Indiana', 'KS': 'Kansas', 'KY': 'Kentucky',
    'LA': 'Louisiana', 'MA': 'Massachusetts', 'MD': 'Maryland',
    'ME': 'Maine', 'MI': 'Michigan', 'MN': 'Minnesota',
    'MO': 'Missouri', 'MS': 'Mississippi', 'MT': 'Montana',
    'NC': 'North Carolina', 'ND': 'North Dakota', 'NE': 'Nebraska',
    'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico',
    'NV': 'Nevada', 'NY': 'New York', 'OH': 'Ohio', 'OK': 'Oklahoma',
    'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island',
    'SC': 'South Carolina', 'SD': 'South Dakota', 'TN': 'Tennessee',
    'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia', 'VT': 'Vermont',
    'WA': 'Washington', 'WI': 'Wisconsin', 'WV': 'West Virginia',
    'WY': 'Wyoming'
}
df["state"] = df["state"].map(state_map)
# 'sex' sütunundaki değerleri yeni değerlerle eşleyelim
df.head()
# Out:
#     state gender  year      name  count
# 0  Alaska      F  1910      Mary     14
# 1  Alaska      F  1910     Annie     12
# 2  Alaska      F  1910      Anna     10
# 3  Alaska      F  1910  Margaret      8
# 4  Alaska      F  1910     Helen      7

# %%
# Rename gender labels
df['gender'] = df['gender'].map({'F': 'female', 'M': 'male'})
# Generate gender based total counts
df['total_count'] = df.groupby(['state','gender', 'year'])['count'].transform('sum')
df.head()
# Out:
#     state  gender  year      name  count  total_count
# 0  Alaska  female  1910      Mary     14           68
# 1  Alaska  female  1910     Annie     12           68
# 2  Alaska  female  1910      Anna     10           68
# 3  Alaska  female  1910  Margaret      8           68
# 4  Alaska  female  1910     Helen      7           68

# %%
df[df["state"]=="Pennsylvania"].shape
# Out:
# (219263, 6)

# %%
# Create rank column
df['rank'] = df.groupby(['year', 'gender','state'])['count'].rank(ascending=False, method='min').astype(int)

# Sonuçları 'count' ve 'rank' sütunlarına göre sıralayarak kontrol edelim
df = df.sort_values(by=['year', 'gender', 'rank'])

# %%
df[(df["year"]==2025) & (df["gender"]=="female")].head(44)
# Out:
#                         state  gender  year       name  count  total_count  \
# 15693                  Alaska  female  2025  Charlotte     32         1653
# 109353                Alabama  female  2025  Charlotte    224        18319
# 236678               Arkansas  female  2025  Charlotte    148        10593
# 361303                Arizona  female  2025     Olivia    353        28219
# 666891             California  female  2025     Olivia   1796       161724
# 912724               Colorado  female  2025  Charlotte    293        23327
# 1017192           Connecticut  female  2025  Charlotte    176        11503
# 1088396  District of Columbia  female  2025       Emma     36         2019
# 1088397  District of Columbia  female  2025     Sophia     36         2019
# 1135240              Delaware  female  2025        Mia     43         2255
# 1282891               Florida  female  2025     Olivia   1020        86762
# 1499142               Georgia  female  2025     Amelia    450        45209
# 1623789                Hawaii  female  2025       Isla     40         2145
# 1707402                  Iowa  female  2025  Charlotte    158        11772
# 1787275                 Idaho  female  2025  Charlotte    104         7164
# 1959986              Illinois  female  2025     Olivia    501        44329
# 2154826               Indiana  female  2025  Charlotte    351        27908
# 2279184                Kansas  female  2025  Charlotte    178        11808
# 2396984              Kentucky  female  2025     Amelia    212        17251
# 2541592             Louisiana  female  2025     Amelia    212        16370
# 2691606         Massachusetts  female  2025  Charlotte    348        24031
# 2817269              Maryland  female  2025     Ailany    225        19985
# 2902287                 Maine  female  2025  Charlotte     89         3115
# 3039427              Michigan  female  2025  Charlotte    381        35731
# 3197623             Minnesota  female  2025  Charlotte    238        21479
# 3338914              Missouri  female  2025  Charlotte    334        24299
# 3472433           Mississippi  female  2025     Amelia    105         8900
# 3555491               Montana  female  2025  Charlotte     46         2825
# 3683509        North Carolina  female  2025     Amelia    459        46483
# 3799411          North Dakota  female  2025  Charlotte     42         2700
# 3865377              Nebraska  female  2025  Charlotte     95         7096
# 3925547         New Hampshire  female  2025  Charlotte     80         3797
# 4039717            New Jersey  female  2025       Emma    428        35500
# 4157413            New Mexico  female  2025        Mia     66         4673
# 4224854                Nevada  female  2025     Olivia    146         9201
# 4435271              New York  female  2025       Emma    774        78329
# 4701873                  Ohio  female  2025  Charlotte    551        47271
# 4865609              Oklahoma  female  2025     Olivia    178        14780
# 4977610                Oregon  female  2025  Charlotte    167        13052
# 5146068          Pennsylvania  female  2025  Charlotte    560        46688
# 5265621          Rhode Island  female  2025  Charlotte     49         2452
# 5353581        South Carolina  female  2025  Charlotte    249        18290
# 5441149          South Dakota  female  2025     Lainey     50         3052
# 5551302             Tennessee  female  2025  Charlotte    423        32074
#
#          rank
# 15693       1
# 109353      1
# 236678      1
# 361303      1
# 666891      1
# 912724      1
# 1017192     1
# 1088396     1
# 1088397     1
# 1135240     1
# 1282891     1
# 1499142     1
# 1623789     1
# 1707402     1
# 1787275     1
# 1959986     1
# 2154826     1
# 2279184     1
# 2396984     1
# 2541592     1
# 2691606     1
# 2817269     1
# 2902287     1
# 3039427     1
# 3197623     1
# 3338914     1
# 3472433     1
# 3555491     1
# 3683509     1
# 3799411     1
# 3865377     1
# 3925547     1
# 4039717     1
# 4157413     1
# 4224854     1
# 4435271     1
# 4701873     1
# 4865609     1
# 4977610     1
# 5146068     1
# 5265621     1
# 5353581     1
# 5441149     1
# 5551302     1

# %%
# Save to Parquet
df.to_parquet("data/preprocessed/usa/names_usa_states.parquet", engine="pyarrow", index=False)

# %%
# Read the saved file for checking
# import polars as pl
df = pl.read_parquet("data/preprocessed/usa/names_usa_states.parquet")
df.head()
# Out:
# shape: (5, 7)
# ┌────────────┬────────┬──────┬──────┬───────┬─────────────┬──────┐
# │ state      ┆ gender ┆ year ┆ name ┆ count ┆ total_count ┆ rank │
# │ ---        ┆ ---    ┆ ---  ┆ ---  ┆ ---   ┆ ---         ┆ ---  │
# │ str        ┆ str    ┆ i64  ┆ str  ┆ i64   ┆ i64         ┆ i32  │
# ╞════════════╪════════╪══════╪══════╪═══════╪═════════════╪══════╡
# │ Alaska     ┆ female ┆ 1910 ┆ Mary ┆ 14    ┆ 68          ┆ 1    │
# │ Alabama    ┆ female ┆ 1910 ┆ Mary ┆ 875   ┆ 13102       ┆ 1    │
# │ Arkansas   ┆ female ┆ 1910 ┆ Mary ┆ 408   ┆ 7539        ┆ 1    │
# │ Arizona    ┆ female ┆ 1910 ┆ Mary ┆ 74    ┆ 586         ┆ 1    │
# │ California ┆ female ┆ 1910 ┆ Mary ┆ 295   ┆ 5950        ┆ 1    │
# └────────────┴────────┴──────┴──────┴───────┴─────────────┴──────┘

# %%
temp = df.filter( pl.col("year") ==1915)
temp.filter(pl.col("name")=="Ethan")
# Out:
# shape: (0, 7)
# ┌───────┬────────┬──────┬──────┬───────┬─────────────┬──────┐
# │ state ┆ gender ┆ year ┆ name ┆ count ┆ total_count ┆ rank │
# │ ---   ┆ ---    ┆ ---  ┆ ---  ┆ ---   ┆ ---         ┆ ---  │
# │ str   ┆ str    ┆ i64  ┆ str  ┆ i64   ┆ i64         ┆ i32  │
# ╞═══════╪════════╪══════╪══════╪═══════╪═════════════╪══════╡
# └───────┴────────┴──────┴──────┴───────┴─────────────┴──────┘

# %%
import geopandas as gpd

url = "https://raw.githubusercontent.com/PublicaMundi/MappingAPI/master/data/geojson/us-states.json"
gdf = gpd.read_file(url)[["name","geometry"]]
gdf.head()
# Out:
#          name                                           geometry
# 0     Alabama  POLYGON ((-87.3593 35.00118, -85.60668 34.9847...
# 1      Alaska  MULTIPOLYGON (((-131.60202 55.11798, -131.5691...
# 2     Arizona  POLYGON ((-109.0425 37.00026, -109.04798 31.33...
# 3    Arkansas  POLYGON ((-94.47384 36.50186, -90.15254 36.496...
# 4  California  POLYGON ((-123.23326 42.00619, -122.37885 42.0...

# %%
import geopandas as gpd
gdf.rename(columns={"name":"state"},inplace=True)
gdf.to_parquet("data/preprocessed/usa/usa_states_geo.parquet")

print(gdf.head())
# Out:
#         state                                           geometry
# 0     Alabama  POLYGON ((-87.3593 35.00118, -85.60668 34.9847...
# 1      Alaska  MULTIPOLYGON (((-131.60202 55.11798, -131.5691...
# 2     Arizona  POLYGON ((-109.0425 37.00026, -109.04798 31.33...
# 3    Arkansas  POLYGON ((-94.47384 36.50186, -90.15254 36.496...
# 4  California  POLYGON ((-123.23326 42.00619, -122.37885 42.0...

# %%
print(gdf.shape)
# Out:
# (52, 2)

# %%
# PREPROCESSING NATIONAL DATA

# %%
import pandas as pd
import os
import polars as pl
# folder containing your files<
folder_path = "data/raw/names-usa/national-data"

# list all files (adjust extension if needed)
files = [f for f in os.listdir(folder_path) if f.endswith(".txt")]

df_list = []

for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path,header=None,names=["name", "gender", "count"])
    df["year"] = int(file[3:7])
    df_list.append(df)

# combine all files into one dataframe
df = pd.concat(df_list, ignore_index=True)
df.head(3)
# Out:
#    name gender  count  year
# 0  Mary      F   7065  1880
# 1  Anna      F   2604  1880
# 2  Emma      F   2003  1880

# %%
# Rename gender labels
df['gender'] = df['gender'].map({'F': 'female', 'M': 'male'})
df.head(3)
# Out:
#    name  gender  count  year
# 0  Mary  female   7065  1880
# 1  Anna  female   2604  1880
# 2  Emma  female   2003  1880

# %%
df[df["name"]=="Mason"]
# Out:
#           name  gender  count  year
# 1312     Mason    male     22  1880
# 3434     Mason    male     13  1881
# 5528     Mason    male     12  1882
# 7661     Mason    male     12  1883
# 9833     Mason    male     14  1884
# ...        ...     ...    ...   ...
# 2103396  Mason    male   7257  2023
# 2120717  Mason  female     51  2024
# 2135275  Mason    male   6471  2024
# 2152629  Mason  female     51  2025
# 2166812  Mason    male   6291  2025
#
# [196 rows x 4 columns]

# %%
# Save to Parquet
df.to_parquet("data/preprocessed/usa/names_usa_nation.parquet", engine="pyarrow", index=False)
